# %% [markdown]
# # Workflows in Victor
#
# Learn to create multi-step workflows using StateGraph.
#
# ## Basic StateGraph
#
# Create a simple workflow:

# %%
from victor.framework.graph import StateGraph, END

# Define the workflow
def analyze(state):
    return {"analysis": "Analyzed: " + state["input"]}

def summarize(state):
    return {"summary": "Summary: " + state["analysis"]}

# Build graph
workflow = StateGraph()
workflow.add_node("analyze", analyze)
workflow.add_node("summarize", summarize)
workflow.add_edge("analyze", "summarize")
workflow.add_edge("summarize", END)
workflow.set_entry_point("analyze")

# Compile and run
app = workflow.compile()
result = await app.invoke({"input": "Hello Victor!"})
print(result)

# %% [markdown]
# ## Continue to [03_tools.ipynb](./03_tools.ipynb)
